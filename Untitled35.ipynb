# %%
import re
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

nltk.download('stopwords')

text = "The quick BROWN foxes... they are JUMPING 10 lazy dogs!"

text = text.lower()

text = re.sub(r"[^a-z\s]", "", text)

stemmer = PorterStemmer()

stop_words = set(stopwords.words('english'))

res = [stemmer.stem(word) for word in text.split() if word not in stop_words]

print(res)
# Out:
# ['quick', 'brown', 'fox', 'jump', 'lazi', 'dog']
# [nltk_data] Downloading package stopwords to C:\Users\MRUH
# [nltk_data]     45\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('omw-1.4')

text = "cats are running better"
words = text.split()

lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(word) for word in words]

print(lemmas)
# Out:
# ['cat', 'are', 'running', 'better']
# [nltk_data] Downloading package wordnet to C:\Users\MRUH
# [nltk_data]     45\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\MRUH
# [nltk_data]     45\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
spam_words = ["we", "cash", "free"]

sentences = [
    "You can get cash now!",
    "This is a normal message.",
    "We are giving away free gifts!"
]

for sentence in sentences:
    words = sentence.lower().split()
    if any(spam_word in words for spam_word in spam_words):
        print(f"SPAM: {sentence}")
    else:
        print(f"NOT SPAM: {sentence}")
# Out:
# SPAM: You can get cash now!
# NOT SPAM: This is a normal message.
# SPAM: We are giving away free gifts!

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

text = "this is a simple example for stop word removal"
words = text.split()

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word not in stop_words]

print(filtered_words)
# Out:
# ['simple', 'example', 'stop', 'word', 'removal']
# [nltk_data] Downloading package stopwords to C:\Users\MRUH
# [nltk_data]     45\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import math

# Language Model: P(s)
language_model = {
    "hello world": 0.4,
    "hello word": 0.1,
    "yellow world": 0.3,
    "mellow world": 0.2
}

# Channel Model: P(r | s)
channel_model = {
    ("hello world", "hello world"): 0.5,
    ("hello world", "hello word"): 0.2,
    ("hello world", "yellow world"): 0.2,
    ("hello world", "mellow world"): 0.1
}

def noisy_channel_decode(received_message):
    best_sentence = None
    best_score = -math.inf

    for s in language_model:
        P_s = language_model[s]
        P_r_given_s = channel_model.get((received_message, s), 0)

        if P_r_given_s > 0:
            score = math.log(P_r_given_s) + math.log(P_s)
            if score > best_score:
                best_score = score
                best_sentence = s

    return best_sentence


# Test
observed = "hello world"
print("Decoded sentence:", noisy_channel_decode(observed))
# Out:
# Decoded sentence: hello world
